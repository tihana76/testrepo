# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tihana Leder**
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because this is currently my dream job. Also, I am working towards becoming a financial controller at my current job and I think this new data science knowledge could contribute to me becoming even better at this new position_

# %% [markdown]
# ### Code below will calculate my current age

# %%
2022 - 1996
# Out:
# 26

# %% [markdown]
# ~~strikethrough~~

# %% [markdown]
# https://www.youtube.com/watch?v=WANNqr-vcx0&list=PLNIL6PfePTc7RzQUNE6GVKTlImtdkxsoV&index=13

# %% [markdown]
# ![sun.JPG](attachment:184a412f-471c-4d18-aca3-3ec9c83de6b1.JPG)

# %%
5 * 5 * 5
# Out:
# 125

# %% [markdown]
# - one
# - two
# - three

# %% [markdown]
# 1. one
# 2. two
# 3. three

# %% [markdown]
# | one | two | three |
# | --- | --- | --- |
#    | 1 | 2 | 3 |

# %% [markdown]
# > "How wonderful yellow is. It stands for the sun" - Vincent Van Gogh
